# %%
category_mapping = {
    "Home Supplies": [
        "Home Organizers",
        "Bathroom Supplies",
        "Home Decor",
        "Home Care Supplies",
        "Laundry Tools & Accessories",
        "Festive & Party Supplies",
        "Miscellaneous Home"
    ],
    "Kitchenware": [
        "Barbecue",
        "Bar & Wine Utensils",
        "Bakeware",
        "Cookware",
        "Cutlery & Tableware",
        "Drinkware",
        "Kitchen Utensils & Gadgets",
        "Tea & Coffeeware",
        "Kitchen Knives"
    ],
    "Phones & Electronics": [
        "Phone Accessories",
        "Cameras & Photography",
        "Audio & Video",
        "Gaming & Consoles",
        "Smart & Wearable Devices",
        "Education Devices",
        "Universal Accessories",
        "Tablet & Computer Accessories",
        "Phones & Tablets"
    ],
    "Beauty & Personal Care": [
        "Men's Care",
        "Personal Care Appliances",
        "Eye & Ear Care",
        "Nasal & Oral Care",
        "Feminine Care",
        "Perfume",
        "Special Personal Care",
        "Makeup",
        "Skincare",
        "Haircare & Styling",
        "Hand, Foot & Nail Care",
        "Bath & Body Care"
    ],
    "Shoes": [
        "Women's Shoes",
        "Men's Shoes",
        "Shoe Accessories"
    ],
    "Womenswear & Underwear": [
        "Women's Tops",
        "Women's Bottoms",
        "Women's Dresses",
        "Women's Special Clothing",
        "Women's Suits & Overalls",
        "Women's Underwear",
        "Women's Sleepwear & Loungewear"
    ],
    "Household Appliances": [
        "Kitchen Appliances",
        "Home Appliances",
        "Large Home Appliances",
        "Commercial Appliances"
    ],
    "Textiles & Soft Furnishings": [
        "Bedding",
        "Household Textiles",
        "Fabrics & Sewing Supplies"
    ],
    "Sports & Outdoor": [
        "Sport & Outdoor Clothing",
        "Sports Footwear",
        "Sports & Outdoor Accessories",
        "Ball Sports Equipment",
        "Water Sports Equipment",
        "Winter Sports Equipment",
        "Fitness Equipment",
        "Camping & Hiking Equipment",
        "Leisure & Outdoor Recreation Equipment",
        "Swimwear, Surfwear & Wetsuits",
        "Fan Shop"
    ],
    "Baby & Maternity": [
        "Nursing & Feeding",
        "Maternity Supplies"
    ],
    "Pet Supplies": [
        "Dog & Cat Healthcare",
        "Dog & Cat Accessories",
        "Fish & Aquatic Supplies",
        "Reptile & Amphibian Supplies",
        "Bird Supplies",
        "Small Animal Supplies",
        "Farm Animal & Poultry Supplies",
        "Dog & Cat Food",
        "Dog & Cat Furniture",
        "Dog & Cat Clothing",
        "Dog & Cat Litter",
        "Dog & Cat Grooming"
    ],
    "Computers & Office Equipment": [
        "Desktop Computers, Laptops & Tablets",
        "Desktop & Laptop Components",
        "Computer Accessories",
        "Data Storage & Software",
        "Network Components",
        "Office Equipment",
        "Office Stationery & Supplies"
    ],
    "Automotive & Motorcycle": [
        "Car Electronics",
        "Car Exterior Accessories",
        "Car Interior Accessories",
        "Car Repair Tools",
        "Car Lights",
        "Quads, Motorhomes & Boats",
        "Car Washing & Maintenance",
        "Motorcycle Accessories"
    ],
    "Home Improvement": [
        "Electrical Equipment & Supplies",
        "Kitchen Fixtures",
        "Smart Home Systems",
        "Building Supplies",
        "Bathroom Fixtures",
        "Security & Safety",
        "Garden Supplies",
        "Solar & Wind Power",
        "Lights & Lighting"
    ],
    "Tools & Hardware": [
        "Power Tools",
        "Hand Tools",
        "Measuring Tools",
        "Garden Tools",
        "Soldering Equipment",
        "Tool Organizers",
        "Hardware",
        "Pumps & Plumbing"
    ],
    "Furniture": [
        "Indoor Furniture",
        "Outdoor Furniture",
        "Commercial Furniture"
    ],
    "Toys & Hobbies": [
        "Educational Toys",
        "Sports & Outdoor Play",
        "Electric & Remote Control Toys",
        "Games & Puzzles",
        "Classic & Novelty Toys",
        "Musical Instruments & Accessories",
        "DIY"
    ],
    "Collectibles": [
        "Contemporary Culture Collectibles",
        "Trading Cards & Accessories",
        "Sports Collectibles",
        "Entertainment"
    ],
    "Jewelry Accessories & Derivatives": [
        "Non-natural Crystal",
        "Jade",
        "Semiprecious Stones",
        "Artificial Gemstones",
        "Pearl",
        "Amber",
        "Mellite",
        "Platinum & Carat Gold",
        "Silver",
        "Natural Crystal"
    ],
    "Luggage & Bags": [
        "Women's Bags",
        "Men's Bags",
        "Luggage & Travel Bags",
        "Functional Bags",
        "Bag Accessories"
    ],
    "Menswear & Underwear": [
        "Men's Tops",
        "Men's Bottoms",
        "Men's Special Clothing",
        "Men's Underwear",
        "Men's Sleepwear & Loungewear",
        "Men's Suits & Overalls"
    ],
    "Books, Magazines & Audio": [
        "Literature & Art",
        "Economics & Management",
        "Children's & Infants' Books",
        "Science & Technology",
        "Lifestyle & Hobbies",
        "Education & Schooling",
        "Humanities & Social Sciences",
        "Magazines & Newspapers",
        "Video & Music"
    ],
    "Health": [
        "Food Supplements",
        "Medical Supplies",
        "Alternative Medications & Treatments"
    ],
    "Food & Beverages": [
        "Milk & Dairy",
        "Drinks",
        "Instant Food",
        "Staples & Cooking Essentials",
        "Baking",
        "Snacks"
    ],
    "Fashion Accessories": [
        "Hair Extensions & Wigs",
        "Dressmaking Fabrics",
        "Clothes Accessories",
        "Eyewear",
        "Watches & Accessories",
        "Costume Jewelry & Accessories",
        "Hair Accessories"
    ]
}

# %%
df = pd.read_csv('/Users/xiechen/Desktop/masterpool/string_masterpool_updated.csv', dtype=str)
df.fillna('', inplace=True)
df_subset = df[['tt_handles', 'main_category', 'detailed_category']]
df_subset['merged_category'] = df_subset['main_category'] + ', ' + df_subset['detailed_category']
output_path = '/Users/xiechen/Desktop/merged_categories.csv'
df_subset.to_csv(output_path, index=False)
print(f"New CSV file with merged categories has been saved to {output_path}")
# Out:
# New CSV file with merged categories has been saved to /Users/xiechen/Desktop/merged_categories.csv

# %%
#Main and detailed合到一起, 保留
#分开mapping找main and detailed category，然后分成两列，No Match填写空
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

df_merged = pd.read_csv('/Users/xiechen/Desktop/merged_categories.csv', dtype=str)
df = pd.read_csv('/Users/xiechen/Desktop/masterpool/string_masterpool_updated.csv', dtype=str)
df.fillna('', inplace=True)

tt_handles = df['tt_handles'].tolist()
original_main_categories = df['main_category'].tolist()
original_detailed_categories = df['detailed_category'].tolist()

category_mapping = {
    "Home Supplies": [
        "Home Organizers",
        "Bathroom Supplies",
        "Home Decor",
        "Home Care Supplies",
        "Laundry Tools & Accessories",
        "Festive & Party Supplies",
        "Miscellaneous Home"
    ],
    "Kitchenware": [
        "Barbecue",
        "Bar & Wine Utensils",
        "Bakeware",
        "Cookware",
        "Cutlery & Tableware",
        "Drinkware",
        "Kitchen Utensils & Gadgets",
        "Tea & Coffeeware",
        "Kitchen Knives"
    ],
    "Phones & Electronics": [
        "Phone Accessories",
        "Cameras & Photography",
        "Audio & Video",
        "Gaming & Consoles",
        "Smart & Wearable Devices",
        "Education Devices",
        "Universal Accessories",
        "Tablet & Computer Accessories",
        "Phones & Tablets"
    ],
    "Beauty & Personal Care": [
        "Men's Care",
        "Personal Care Appliances",
        "Eye & Ear Care",
        "Nasal & Oral Care",
        "Feminine Care",
        "Perfume",
        "Special Personal Care",
        "Makeup",
        "Skincare",
        "Haircare & Styling",
        "Hand, Foot & Nail Care",
        "Bath & Body Care"
    ],
    "Shoes": [
        "Women's Shoes",
        "Men's Shoes",
        "Shoe Accessories"
    ],
    "Womenswear & Underwear": [
        "Women's Tops",
        "Women's Bottoms",
        "Women's Dresses",
        "Women's Special Clothing",
        "Women's Suits & Overalls",
        "Women's Underwear",
        "Women's Sleepwear & Loungewear"
    ],
    "Household Appliances": [
        "Kitchen Appliances",
        "Home Appliances",
        "Large Home Appliances",
        "Commercial Appliances"
    ],
    "Textiles & Soft Furnishings": [
        "Bedding",
        "Household Textiles",
        "Fabrics & Sewing Supplies"
    ],
    "Sports & Outdoor": [
        "Sport & Outdoor Clothing",
        "Sports Footwear",
        "Sports & Outdoor Accessories",
        "Ball Sports Equipment",
        "Water Sports Equipment",
        "Winter Sports Equipment",
        "Fitness Equipment",
        "Camping & Hiking Equipment",
        "Leisure & Outdoor Recreation Equipment",
        "Swimwear, Surfwear & Wetsuits",
        "Fan Shop"
    ],
    "Baby & Maternity": [
        "Nursing & Feeding",
        "Maternity Supplies"
    ],
    "Pet Supplies": [
        "Dog & Cat Healthcare",
        "Dog & Cat Accessories",
        "Fish & Aquatic Supplies",
        "Reptile & Amphibian Supplies",
        "Bird Supplies",
        "Small Animal Supplies",
        "Farm Animal & Poultry Supplies",
        "Dog & Cat Food",
        "Dog & Cat Furniture",
        "Dog & Cat Clothing",
        "Dog & Cat Litter",
        "Dog & Cat Grooming"
    ],
    "Computers & Office Equipment": [
        "Desktop Computers, Laptops & Tablets",
        "Desktop & Laptop Components",
        "Computer Accessories",
        "Data Storage & Software",
        "Network Components",
        "Office Equipment",
        "Office Stationery & Supplies"
    ],
    "Automotive & Motorcycle": [
        "Car Electronics",
        "Car Exterior Accessories",
        "Car Interior Accessories",
        "Car Repair Tools",
        "Car Lights",
        "Quads, Motorhomes & Boats",
        "Car Washing & Maintenance",
        "Motorcycle Accessories"
    ],
    "Home Improvement": [
        "Electrical Equipment & Supplies",
        "Kitchen Fixtures",
        "Smart Home Systems",
        "Building Supplies",
        "Bathroom Fixtures",
        "Security & Safety",
        "Garden Supplies",
        "Solar & Wind Power",
        "Lights & Lighting"
    ],
    "Tools & Hardware": [
        "Power Tools",
        "Hand Tools",
        "Measuring Tools",
        "Garden Tools",
        "Soldering Equipment",
        "Tool Organizers",
        "Hardware",
        "Pumps & Plumbing"
    ],
    "Furniture": [
        "Indoor Furniture",
        "Outdoor Furniture",
        "Commercial Furniture"
    ],
    "Toys & Hobbies": [
        "Educational Toys",
        "Sports & Outdoor Play",
        "Electric & Remote Control Toys",
        "Games & Puzzles",
        "Classic & Novelty Toys",
        "Musical Instruments & Accessories",
        "DIY"
    ],
    "Collectibles": [
        "Contemporary Culture Collectibles",
        "Trading Cards & Accessories",
        "Sports Collectibles",
        "Entertainment"
    ],
    "Jewelry Accessories & Derivatives": [
        "Non-natural Crystal",
        "Jade",
        "Semiprecious Stones",
        "Artificial Gemstones",
        "Pearl",
        "Amber",
        "Mellite",
        "Platinum & Carat Gold",
        "Silver",
        "Natural Crystal"
    ],
    "Luggage & Bags": [
        "Women's Bags",
        "Men's Bags",
        "Luggage & Travel Bags",
        "Functional Bags",
        "Bag Accessories"
    ],
    "Menswear & Underwear": [
        "Men's Tops",
        "Men's Bottoms",
        "Men's Special Clothing",
        "Men's Underwear",
        "Men's Sleepwear & Loungewear",
        "Men's Suits & Overalls"
    ],
    "Books, Magazines & Audio": [
        "Literature & Art",
        "Economics & Management",
        "Children's & Infants' Books",
        "Science & Technology",
        "Lifestyle & Hobbies",
        "Education & Schooling",
        "Humanities & Social Sciences",
        "Magazines & Newspapers",
        "Video & Music"
    ],
    "Health": [
        "Food Supplements",
        "Medical Supplies",
        "Alternative Medications & Treatments"
    ],
    "Food & Beverages": [
        "Milk & Dairy",
        "Drinks",
        "Instant Food",
        "Staples & Cooking Essentials",
        "Baking",
        "Snacks"
    ],
    "Fashion Accessories": [
        "Hair Extensions & Wigs",
        "Dressmaking Fabrics",
        "Clothes Accessories",
        "Eyewear",
        "Watches & Accessories",
        "Costume Jewelry & Accessories",
        "Hair Accessories"
    ]
}

main_category_keys = list(category_mapping.keys())
detailed_category_values = [item for sublist in category_mapping.values() for item in sublist]

main_vectorizer = TfidfVectorizer().fit(main_category_keys)
detailed_vectorizer = TfidfVectorizer().fit(detailed_category_values)

main_category_vectors = main_vectorizer.transform(main_category_keys)
detailed_category_vectors = detailed_vectorizer.transform(detailed_category_values)

# Function to find the top matches using TF-IDF and Cosine Similarity
def find_top_matches(category, vectorizer, category_vectors, all_categories, n=3):
    if not category: 
        return ['No Match']
    
    category_vector = vectorizer.transform([category])
    similarities = cosine_similarity(category_vector, category_vectors).flatten()
    top_indices = similarities.argsort()[-n:][::-1]
    return [all_categories[i] for i in top_indices if similarities[i] > 0.4]  

matched_main_categories = []
for main_category in original_main_categories:
    matches = find_top_matches(main_category, main_vectorizer, main_category_vectors, main_category_keys)
    matched_main_categories.append(', '.join(matches))

matched_detailed_categories = []
for detailed_category in original_detailed_categories:
    matches = find_top_matches(detailed_category, detailed_vectorizer, detailed_category_vectors, detailed_category_values)
    matched_detailed_categories.append(', '.join(matches))

# Combine all categories in the mapping into a single list for comparison
all_categories = []
for main_cat, detailed_cats in category_mapping.items():
    all_categories.append(main_cat)
    all_categories.extend(detailed_cats)

# Function to find the top matches using TF-IDF
def find_top_matches_tfidf(query, choices, threshold=0.2, n=5):
    # Combine the query with the choices into a single list
    all_texts = [query] + choices
    
    # Create TF-IDF vectorizer and fit on the combined texts
    vectorizer = TfidfVectorizer().fit_transform(all_texts)
    
    # Compute cosine similarity between the query and all choices
    cosine_similarities = cosine_similarity(vectorizer[0:1], vectorizer[1:]).flatten()
    
    # Get top n matches based on similarity scores
    top_indices = cosine_similarities.argsort()[-n:][::-1]
    top_matches = [choices[i] for i in top_indices if cosine_similarities[i] >= threshold]
    
    return top_matches if top_matches else ['']

# Apply similarity matching for all rows and store the results
matched_categories = []
for index, row in df_merged.iterrows():
    merged_category = row['merged_category']
    top_matches = find_top_matches_tfidf(merged_category, all_categories)
    
    # Combine matched categories into a single string separated by commas
    matched_categories_str = ', '.join(top_matches)
    
    matched_categories.append(matched_categories_str)

# Add the matched categories to the DataFrame
df_merged['matched_categories'] = matched_categories

# Save the updated DataFrame back to the CSV, overwriting the old file
df_merged.to_csv('/Users/xiechen/Desktop/matched_merged_categories.csv', index=False)
print("Updated file saved successfully.")
# Out:
# Updated file saved successfully.

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

merged_df = pd.read_csv('/Users/xiechen/Desktop/merged_categories.csv', dtype=str)
string_masterpool_df = pd.read_csv('/Users/xiechen/Desktop/masterpool/string_masterpool_updated.csv', dtype=str)

merged_df.fillna('', inplace=True)
string_masterpool_df.fillna('', inplace=True)

merged_categories = merged_df['merged_category'].tolist()
tt_handles = string_masterpool_df['tt_handles'].tolist()
original_main_categories = string_masterpool_df['main_category'].tolist()
original_detailed_categories = string_masterpool_df['detailed_category'].tolist()

# Main category and detailed category mappings
main_category_mapping = [
    "Home Supplies", "Kitchenware", "Phones & Electronics", "Beauty & Personal Care", 
    "Shoes", "Womenswear & Underwear", "Household Appliances", "Textiles & Soft Furnishings",
    "Sports & Outdoor", "Baby & Maternity", "Pet Supplies", "Computers & Office Equipment", 
    "Automotive & Motorcycle", "Home Improvement", "Tools & Hardware", "Furniture", 
    "Toys & Hobbies", "Collectibles", "Jewelry Accessories & Derivatives", "Luggage & Bags", 
    "Menswear & Underwear", "Books, Magazines & Audio", "Health", "Food & Beverages", 
    "Fashion Accessories"
]

detailed_category_mapping = [
    "Home Organizers", "Bathroom Supplies", "Home Decor", "Home Care Supplies", 
    "Laundry Tools & Accessories", "Festive & Party Supplies", "Miscellaneous Home",
    "Barbecue", "Bar & Wine Utensils", "Bakeware", "Cookware", "Cutlery & Tableware", 
    "Drinkware", "Kitchen Utensils & Gadgets", "Tea & Coffeeware", "Kitchen Knives", 
    "Phone Accessories", "Cameras & Photography", "Audio & Video", "Gaming & Consoles", 
    "Smart & Wearable Devices", "Education Devices", "Universal Accessories", 
    "Tablet & Computer Accessories", "Phones & Tablets", "Men's Care", 
    "Personal Care Appliances", "Eye & Ear Care", "Nasal & Oral Care", "Feminine Care", 
    "Perfume", "Special Personal Care", "Makeup", "Skincare", "Haircare & Styling", 
    "Hand, Foot & Nail Care", "Bath & Body Care", "Women's Shoes", "Men's Shoes", 
    "Shoe Accessories", "Women's Tops", "Women's Bottoms", "Women's Dresses", 
    "Women's Special Clothing", "Women's Suits & Overalls", "Women's Underwear", 
    "Women's Sleepwear & Loungewear", "Kitchen Appliances", "Home Appliances", 
    "Large Home Appliances", "Commercial Appliances", "Bedding", "Household Textiles", 
    "Fabrics & Sewing Supplies", "Sport & Outdoor Clothing", "Sports Footwear", 
    "Sports & Outdoor Accessories", "Ball Sports Equipment", "Water Sports Equipment", 
    "Winter Sports Equipment", "Fitness Equipment", "Camping & Hiking Equipment", 
    "Leisure & Outdoor Recreation Equipment", "Swimwear, Surfwear & Wetsuits", 
    "Fan Shop", "Nursing & Feeding", "Maternity Supplies", "Dog & Cat Healthcare", 
    "Dog & Cat Accessories", "Fish & Aquatic Supplies", "Reptile & Amphibian Supplies", 
    "Bird Supplies", "Small Animal Supplies", "Farm Animal & Poultry Supplies", 
    "Dog & Cat Food", "Dog & Cat Furniture", "Dog & Cat Clothing", "Dog & Cat Litter", 
    "Dog & Cat Grooming", "Desktop Computers, Laptops & Tablets", "Desktop & Laptop Components", 
    "Computer Accessories", "Data Storage & Software", "Network Components", 
    "Office Equipment", "Office Stationery & Supplies", "Car Electronics", 
    "Car Exterior Accessories", "Car Interior Accessories", "Car Repair Tools", 
    "Car Lights", "Quads, Motorhomes & Boats", "Car Washing & Maintenance", 
    "Motorcycle Accessories", "Electrical Equipment & Supplies", "Kitchen Fixtures", 
    "Smart Home Systems", "Building Supplies", "Bathroom Fixtures", "Security & Safety", 
    "Garden Supplies", "Solar & Wind Power", "Lights & Lighting", "Power Tools", 
    "Hand Tools", "Measuring Tools", "Garden Tools", "Soldering Equipment", 
    "Tool Organizers", "Hardware", "Pumps & Plumbing", "Indoor Furniture", 
    "Outdoor Furniture", "Commercial Furniture", "Educational Toys", 
    "Sports & Outdoor Play", "Electric & Remote Control Toys", "Games & Puzzles", 
    "Classic & Novelty Toys", "Musical Instruments & Accessories", "DIY", 
    "Contemporary Culture Collectibles", "Trading Cards & Accessories", 
    "Sports Collectibles", "Entertainment", "Non-natural Crystal", "Jade", 
    "Semiprecious Stones", "Artificial Gemstones", "Pearl", "Amber", "Mellite", 
    "Platinum & Carat Gold", "Silver", "Natural Crystal", "Women's Bags", 
    "Men's Bags", "Luggage & Travel Bags", "Functional Bags", "Bag Accessories", 
    "Men's Tops", "Men's Bottoms", "Men's Special Clothing", "Men's Underwear", 
    "Men's Sleepwear & Loungewear", "Men's Suits & Overalls", "Literature & Art", 
    "Economics & Management", "Children's & Infants' Books", "Science & Technology", 
    "Lifestyle & Hobbies", "Education & Schooling", "Humanities & Social Sciences", 
    "Magazines & Newspapers", "Video & Music", "Food Supplements", "Medical Supplies", 
    "Alternative Medications & Treatments", "Milk & Dairy", "Drinks", "Instant Food", 
    "Staples & Cooking Essentials", "Baking", "Snacks", "Hair Extensions & Wigs", 
    "Dressmaking Fabrics", "Clothes Accessories", "Eyewear", "Watches & Accessories", 
    "Costume Jewelry & Accessories", "Hair Accessories"
]

# Vectorize main and detailed categories
main_vectorizer = TfidfVectorizer().fit(main_category_mapping)
detailed_vectorizer = TfidfVectorizer().fit(detailed_category_mapping)

main_category_vectors = main_vectorizer.transform(main_category_mapping)
detailed_category_vectors = detailed_vectorizer.transform(detailed_category_mapping)

# Function to find the top matches using TF-IDF and Cosine Similarity
def find_top_matches(category, vectorizer, category_vectors, all_categories, max_results=5, threshold=0.3):
    if not category: 
        return [(' ', 0)]
    
    category_vector = vectorizer.transform([category])
    similarities = cosine_similarity(category_vector, category_vectors).flatten()
    top_indices = similarities.argsort()[-max_results:][::-1]  # Sort in descending order of similarity

    return [(all_categories[i], similarities[i]) for i in top_indices if similarities[i] >= threshold]

matched_main_categories = []
matched_detailed_categories = []

for merged_category in merged_categories:
    top_matches_main = find_top_matches(merged_category, main_vectorizer, main_category_vectors, main_category_mapping, max_results=5)
    top_matches_detailed = find_top_matches(merged_category, detailed_vectorizer, detailed_category_vectors, detailed_category_mapping, max_results=6)

    matched_main = ', '.join([match[0] for match in top_matches_main])
    matched_detailed = ', '.join([match[0] for match in top_matches_detailed])
    
    matched_main_categories.append(matched_main)
    matched_detailed_categories.append(matched_detailed)

result_df = pd.DataFrame({
    'tt_handles': tt_handles,
    'main_category': original_main_categories,
    'detailed_category': original_detailed_categories,
    'matched_main_category': matched_main_categories,
    'matched_detailed_category': matched_detailed_categories
})
result_df.to_csv('/Users/xiechen/Desktop/masterpool/matched_categories_results.csv', index=False)
print("Results saved")
# Out:
# Results saved
